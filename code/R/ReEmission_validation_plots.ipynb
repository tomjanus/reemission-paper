# %% [markdown]
# ### Create valdation plots using ggplot2

# %%
# ---- Load required libraries ----
library(ggplot2)
library(dplyr)
library(readr)
library(gridExtra)
library(grid)
library(gtable)
library(RColorBrewer)

# ---- Helper function: Safe CSV read ----
safe_read_csv <- function(path) {
  if (!file.exists(path)) {
    stop(paste("❌ File not found:", path))
  }
  read_csv(path, show_col_types = FALSE)
}

# ---- Load and prepare data ----
file_x <- file.path("comparison_data", "validation_outputs_comb_30_6.csv")
file_y <- file.path("comparison_data", "results_chris.csv")

df_x <- safe_read_csv(file_x)
df_y <- safe_read_csv(file_y)

# ---- Merge and filter data ----
dams_to_remove <- c("A Laing Ni Dam", "Taninthayi")
res_name_zero_degassing <- "Taninthayi"

merged_df <- inner_join(df_x, df_y, by = "Name") %>%
  mutate(
    CH4degas_gCO2eqm2yr_INT100yr = ifelse(
      Name == res_name_zero_degassing, 0, CH4degas_gCO2eqm2yr_INT100yr
    )
  ) %>%
  filter(!Name %in% dams_to_remove)

# ---- Save merged data ----
csv_output_path <- file.path("..", "outputs_and_intermediate", "merged_data.csv")
dir.create(dirname(csv_output_path), showWarnings = FALSE, recursive = TRUE)
write_csv(merged_df, csv_output_path)

message("✅ Merged data saved to: ", csv_output_path)

# ---- Define comparisons ----
comparisons <- list(
  list(
    y = "co2_diffusion",
    x = "CO2yrdiff_gCO2eqm2yr_GROSSINTEG",
    xlab = expression(CO[2]~Diffusion~(Gres)),
    ylab = expression(CO[2]~Diffusion~(ReEmission)),
    title = expression(CO[2]~Diffusion)
  ),
  list(
    y = "ch4_diffusion",
    x = "CH4yrdiff_gCO2eqm2yr_.INTEG",
    xlab = expression(CH[4]~Diffusion~(Gres)),
    ylab = expression(CH[4]~Diffusion~(ReEmission)),
    title = expression(CH[4]~Diffusion)
  ),
  list(
    y = "ch4_ebullition",
    x = "CH4ebull_gCO2eqm2yr",
    xlab = expression(CH[4]~Ebullition~(Gres)),
    ylab = expression(CH[4]~Ebullition~(ReEmission)),
    title = expression(CH[4]~Ebullition)
  ),
  list(
    y = "ch4_degassing",
    x = "CH4degas_gCO2eqm2yr_INT100yr",
    xlab = expression(CH[4]~Degassing~(Gres)),
    ylab = expression(CH[4]~Degassing~(ReEmission)),
    title = expression(CH[4]~Degassing)
  )
)

# ---- Plotting function ----
create_plot <- function(data, cmp, show_legend = FALSE) {
  # Check column presence
  if (!all(c(cmp$x, cmp$y) %in% names(data))) {
    stop(paste("❌ Missing columns for comparison:", cmp$title))
  }
  
  # Compute R²
  x <- data[[cmp$x]]
  y <- data[[cmp$y]]
  r2_val <- summary(lm(y ~ x))$r.squared
  r2_label <- bquote(R^2 == .(formatC(r2_val, digits = 3, format = "f")))
  
  ggplot(data, aes_string(x = cmp$x, y = cmp$y)) +
    geom_point(
      aes(
        shape = factor(type),
        fill = catchment.biogenic_factors.climate,
        size = reservoir.area
      ),
      alpha = 0.9, color = "grey30", shape = 21, stroke = 0.35
    ) +
    geom_smooth(method = "lm", se = FALSE, color = "grey30", size = 0.5) +
    geom_abline(intercept = 0, slope = 1, colour = "gray17",
                linewidth = 0.7, alpha = 0.6, linetype = 2) +
    annotate("text",
             x = min(x, na.rm = TRUE),
             y = max(y, na.rm = TRUE),
             label = as.expression(r2_label),
             hjust = 0, vjust = 1, size = 4) +
    scale_fill_brewer(palette = "RdBu", name = "Climate\nZone") +
    scale_shape_discrete(name = "Type") +
    scale_size_continuous(name = "Reservoir\nArea (km²)") +
    labs(title = cmp$title, x = cmp$xlab, y = cmp$ylab) +
    guides(
      fill = guide_legend(override.aes = list(size = 4)),
      shape = guide_legend(override.aes = list(size = 4)),
      size = guide_legend(override.aes = list(size = 4))
    ) +
    theme_light(base_size = 10) +
    theme(
      plot.title = element_text(size = 10, hjust = 0.5),
      axis.title = element_text(size = 10, face = "bold", hjust = 0.5),
      axis.text = element_text(size = 9.5),
      panel.grid.major = element_line(color = "gray85"),
      panel.grid.minor = element_blank(),
      axis.line = element_line(color = "black"),
      axis.ticks = element_line(color = "black"),
      panel.border = element_rect(color = "black", fill = NA, linewidth = 0.5),
      legend.position = if (show_legend) "bottom" else "none",
      legend.title = element_text(size = 10, face = "bold"),
      legend.box = "horizontal",
      legend.text = element_text(size = 10),
      legend.key.size = unit(1.2, "lines"),
      legend.key.width = unit(1.5, "lines")
    )
}

# ---- Extract legend ----
extract_legend <- function(p) {
  tmp <- ggplot_gtable(ggplot_build(p))
  leg <- which(sapply(tmp$grobs, function(x) x$name) == "guide-box")
  tmp$grobs[[leg]]
}

# ---- Generate all plots ----
legend_plot <- create_plot(merged_df, comparisons[[1]], show_legend = TRUE)
legend <- extract_legend(legend_plot)

plot_list <- lapply(comparisons, create_plot, data = merged_df, show_legend = FALSE)
grid_plots <- arrangeGrob(grobs = plot_list, ncol = 4)
grid_plots <- gtable_add_col_space(grid_plots, unit(0.5, "cm"))

final_plot <- grid.arrange(grid_plots, legend, heights = c(6, 1), ncol = 1)

# ---- Save outputs ----
output_dir <- file.path("..", "outputs_and_intermediate")
dir.create(output_dir, showWarnings = FALSE, recursive = TRUE)

png_file <- file.path(output_dir, "comparison_plot.png")
svg_file <- file.path(output_dir, "comparison_plot.svg")

ggsave(png_file, final_plot, width = 11.7, height = 3.3, dpi = 600)
ggsave(svg_file, final_plot, width = 11.7, height = 3.3)

message("✅ Plots saved successfully to: ", output_dir)

# %%
# ==============================================================
# Fixed layout for comparison_plot_net_emissions (equal subplot widths)
# ==============================================================
library(cowplot)

# ---- Define second comparison set ----
comparisons_p2 <- list(
  list(y = "co2_preimp", x = "preimpEM.gCO2eqm2yr",
       xlab = expression(CO[2]~Emission~(Gres)),
       ylab = expression(CO[2]~Emission~(ReEmission)),
       title = "Preimpoundment CO₂ Emission"),
  list(y = "ch4_preimp", x = "preimpEM.CH4.gCO2eqm2yr",
       xlab = expression(CH[4]~Emission~(Gres)),
       ylab = expression(CH[4]~Emission~(ReEmission)),
       title = "Preimpoundment CH₄ Emission"),
  list(y = "co2_net", x = "CO2yrdiff_gCO2eqm2yr_NETINTEG.preimpCor",
       xlab = expression(CO[2]~Emission~(Gres)),
       ylab = expression(CO[2]~Emission~(ReEmission)),
       title = "Net CO₂ Emission"),
  list(y = "ch4_net", x = "total_CH4_yr_preimp.cor.gCO2eqm2yr",
       xlab = expression(CH[4]~Emission~(Gres)),
       ylab = expression(CH[4]~Emission~(ReEmission)),
       title = "Net CH₄ Emission")
)

# ---- Generate plots ----
legend_plot_p2 <- create_plot(merged_df, comparisons_p2[[1]], show_legend = TRUE)
legend_p2 <- extract_legend(legend_plot_p2)

plot_list_p2 <- lapply(comparisons_p2, create_plot, data = merged_df, show_legend = FALSE)

# ---- Arrange plots with equal widths using cowplot ----
combined_p2 <- plot_grid(plotlist = plot_list_p2, ncol = 4, align = "hv")

# Add the legend below
final_plot_p2 <- plot_grid(
  combined_p2,
  legend_p2,
  ncol = 1,
  rel_heights = c(1, 0.18)
)

# ---- Save ----
net_emissions_png_file <- file.path("..", "outputs_and_intermediate", "comparison_plot_net_emissions.png")
net_emissions_svg_file <- file.path("..", "outputs_and_intermediate", "comparison_plot_net_emissions.svg")

ggsave(net_emissions_png_file, final_plot_p2, width = 11.7, height = 3.3, dpi = 600)
ggsave(net_emissions_svg_file, final_plot_p2, width = 11.7, height = 3.3)
